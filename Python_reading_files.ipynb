# %% [markdown]
# <a href="https://colab.research.google.com/github/91072puu/SAS_to_R-Python/blob/main/Python_reading_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import files
#uploaded = files.upload()

#Read data
import pandas as pd

#ae=pd.read_sas("ae.xpt", format="xport")
#ae.head()
#ae.describe()

#cm=pd.read_sas("cm.xpt", format="xport")
#cm.head()
#cm.describe()

dm=pd.read_sas("dm.xpt", format="xport")
dm.head()
#dm.describe()
# Out:
#            STUDYID DOMAIN         USUBJID   SUBJID        RFSTDTC  \
# 0  b'CDISCPILOT01'  b'DM'  b'01-701-1015'  b'1015'  b'2014-01-02'
# 1  b'CDISCPILOT01'  b'DM'  b'01-701-1023'  b'1023'  b'2012-08-05'
# 2  b'CDISCPILOT01'  b'DM'  b'01-701-1028'  b'1028'  b'2013-07-19'
# 3  b'CDISCPILOT01'  b'DM'  b'01-701-1033'  b'1033'  b'2014-03-18'
# 4  b'CDISCPILOT01'  b'DM'  b'01-701-1034'  b'1034'  b'2014-07-01'
#
#          RFENDTC       RFXSTDTC       RFXENDTC RFICDTC             RFPENDTC  \
# 0  b'2014-07-02'  b'2014-01-02'  b'2014-07-02'     b''  b'2014-07-02T11:45'
# 1  b'2012-09-02'  b'2012-08-05'  b'2012-09-01'     b''        b'2013-02-18'
# 2  b'2014-01-14'  b'2013-07-19'  b'2014-01-14'     b''  b'2014-01-14T11:10'
# 3  b'2014-04-14'  b'2014-03-18'  b'2014-03-31'     b''        b'2014-09-15'
# 4  b'2014-12-30'  b'2014-07-01'  b'2014-12-30'     b''  b'2014-12-30T09:50'
#
#    ...   SEX      RACE                     ETHNIC      ARMCD  \
# 0  ...  b'F'  b'WHITE'      b'HISPANIC OR LATINO'     b'Pbo'
# 1  ...  b'M'  b'WHITE'      b'HISPANIC OR LATINO'     b'Pbo'
# 2  ...  b'M'  b'WHITE'  b'NOT HISPANIC OR LATINO'  b'Xan_Hi'
# 3  ...  b'M'  b'WHITE'  b'NOT HISPANIC OR LATINO'  b'Xan_Lo'
# 4  ...  b'F'  b'WHITE'  b'NOT HISPANIC OR LATINO'  b'Xan_Hi'
#
#                        ARM   ACTARMCD                   ACTARM COUNTRY  \
# 0               b'Placebo'     b'Pbo'               b'Placebo'  b'USA'
# 1               b'Placebo'     b'Pbo'               b'Placebo'  b'USA'
# 2  b'Xanomeline High Dose'  b'Xan_Hi'  b'Xanomeline High Dose'  b'USA'
# 3   b'Xanomeline Low Dose'  b'Xan_Lo'   b'Xanomeline Low Dose'  b'USA'
# 4  b'Xanomeline High Dose'  b'Xan_Hi'  b'Xanomeline High Dose'  b'USA'
#
#            DMDTC  DMDY
# 0  b'2013-12-26'  -7.0
# 1  b'2012-07-22' -14.0
# 2  b'2013-07-11'  -8.0
# 3  b'2014-03-10'  -8.0
# 4  b'2014-06-24'  -7.0
#
# [5 rows x 25 columns]
